# %%
import pandas as pd

# %%
file_loc="C:/Users/DELL/Downloads/ai_proj/training_data/training_data/cluster_map/cluster_map"


cluster_map=pd.read_csv(file_loc,sep='\t',header=None,names=["region_hash","id_region"])

# %%
file_loc="C:/Users/DELL/Downloads/ai_proj/training_data/training_data/order_data/order_data_2016-01-01"
size = len(file_loc)
order_dets=pd.DataFrame(columns=["order_id","driver_id","passenger_id","start_region_hash","dest_region_hash","Price","Time"])
#=[None] *22
order_deets=pd.DataFrame(columns=["order_id","driver_id","passenger_id","start_region_hash","dest_region_hash","Price","Time"])

#
varrT =1
varrtt=10
for tempp in range(varrT,10):
    last=str(tempp)
    file_loc=file_loc[:- 1]+last
    # print(file_loc)
    
    order_dets = pd.read_csv(file_loc, sep='\t', header=None, names=["order_id","driver_id","passenger_id","start_region_hash","dest_region_hash","Price","Time"])
    order_deets = pd.concat([order_deets, order_dets], ignore_index=True)
print(order_dets)

for tempp in range (varrtt,22):
    last=str(tempp)
    file_loc=file_loc[:- 2]+last
    # print(file_loc)

    order_dets = pd.read_csv(file_loc, sep='\t', header=None, names=["order_id","driver_id","passenger_id","start_region_hash","dest_region_hash","Price","Time"])
    order_deets = pd.concat([order_deets, order_dets], ignore_index=True)
# Out:
#                               order_id                         driver_id  \
# 0     500b72516f730cd9ae2b842e0ad4804e  cbab22f2c4f7341d8bf7525d95d8b901
# 1     1e44d0c8b74fda2f4cdf93543d2da8ae                               NaN
# 2     10b8fd2d9318a1655de4b11311677c2d  f3ab16e5bc2037a39e844358944b20be
# 3     deac031aeea6faf5798dafec75b69c0e  40af518372333a38345efd5d86cdd2de
# 4     a3f36ff28cbbf063813e3e8c51c2bf78  890d0f4a09304f034cdeef44922179a0
# ...                                ...                               ...
# 8571  c598c9633da37c817bcb3e93bd9ec4bd                               NaN
# 8572  64b66e36c6ba9aa40a887b9941a4e4d6  1cd719523c6eed472f8d29b962e55cf6
# 8573  fb4fa58c8b68d7f730381df34e6d7fc1  f391b15959c41a89a28bf92bb21de93e
# 8574  14fcf62e70cfd7505f6f2a8cc0e319de  8d52ae96566aedf10c8f560a18565848
# 8575  4b8ee338dd49c86f6e16c7f78f001b7b  0539234cd9361acdf32181d649261786
#
#                           passenger_id                 start_region_hash  \
# 0     4feb5db8b9f8dddfd33672fb435ab381  364bf755f9b270f0f9141d1a61de43ee
# 1     742a22012a236a828977129c0c2526f0  52a4e8aaa12f70020e889aed8fd5ddbc
# 2     742a22012a236a828977129c0c2526f0  52a4e8aaa12f70020e889aed8fd5ddbc
# 3     627851571d93e2c693b7d06fcab80c6c  2920ece99323b4c111d6f9affc7ea034
# 4     b7df9a45a9e0f6f0f4211a1b9afd8a21  82cc4851f9e4faa4e54309f8bb73fd7c
# ...                                ...                               ...
# 8571  e950bef14e3d7c0d388b686ce5a8025e  d4ec2125aff74eded207d2d915ef682f
# 8572  4357832152a980d7a0cd8a45b7feb913  82cc4851f9e4faa4e54309f8bb73fd7c
# 8573  acd51269448f49043e744f1bb99c8e03  1afd7afbc81ecc1b13886a569d869e8a
# 8574  6d4c0c33fc343570b20a58e6e77476d4  929ec6c160e6f52c20a4217c7978f681
# 8575  d4f32d515be3974516d21a587cded876  364bf755f9b270f0f9141d1a61de43ee
#
#                       dest_region_hash  Price                 Time
# 0     364bf755f9b270f0f9141d1a61de43ee    7.0  2016-01-09 08:11:41
# 1     ca064c2682ca48c6a21de012e87c0df5    5.0  2016-01-09 08:15:57
# 2     ca064c2682ca48c6a21de012e87c0df5    7.0  2016-01-09 08:15:57
# 3     d4ec2125aff74eded207d2d915ef682f   11.0  2016-01-09 16:50:54
# 4     d1ab2cc538d518758a1a82b1787592d4   15.0  2016-01-09 21:09:42
# ...                                ...    ...                  ...
# 8571  9868717243779473e6699d8a7bfce66f   25.0  2016-01-09 22:13:38
# 8572  d4ec2125aff74eded207d2d915ef682f   36.0  2016-01-09 17:27:26
# 8573  d4ec2125aff74eded207d2d915ef682f   20.0  2016-01-09 10:38:03
# 8574  b05379ac3f9b7d99370d443cfd5dcc28   13.0  2016-01-09 01:18:08
# 8575  364bf755f9b270f0f9141d1a61de43ee    7.0  2016-01-09 20:50:15
#
# [8576 rows x 7 columns]

# %%
order_deets.to_csv("all_data1.csv")

# %%
file_loc = "C:/Users/DELL/Downloads/ai_proj/training_data/training_data/weather_data/weather_data_2016-01-01"
size = len(file_loc)
varry=1
vaarr2=10
weather_deets = pd.DataFrame(columns=["Time","Weather","Temprature","PM2.5"])
weather_dets= pd.DataFrame(columns=["Time","Weather","Temprature","PM2.5"])
for tempp in range ( varry,10):
    last=str(tempp)
    file_loc=file_loc[:- 1]+last
    print(file_loc)

    weather_dets= pd.read_csv(file_loc, sep='\t', header=None, names=["Time","Weather","Temprature","PM2.5"])
    weather_deets = pd.concat([weather_deets, weather_dets], ignore_index=True)

for tempp in range(vaarr2,22):
    last=str(tempp)
    file_loc=file_loc[:- 2]+last
    print(file_loc)

    weather_dets = pd.read_csv(file_loc, sep='\t', header=None, names=["Time","Weather","Temprature","PM2.5"])
    weather_deets = pd.concat([weather_deets, weather_dets], ignore_index=True)

print(weather_dets)
#weather_deets.to_csv("all_weather.csv")
# Out:
# C:/Users/DELL/Downloads/ai_proj/training_data/training_data/weather_data/weather_data_2016-01-01
# C:/Users/DELL/Downloads/ai_proj/training_data/training_data/weather_data/weather_data_2016-01-02
# C:/Users/DELL/Downloads/ai_proj/training_data/training_data/weather_data/weather_data_2016-01-03
# C:/Users/DELL/Downloads/ai_proj/training_data/training_data/weather_data/weather_data_2016-01-04
# C:/Users/DELL/Downloads/ai_proj/training_data/training_data/weather_data/weather_data_2016-01-05
# C:/Users/DELL/Downloads/ai_proj/training_data/training_data/weather_data/weather_data_2016-01-06
# C:/Users/DELL/Downloads/ai_proj/training_data/training_data/weather_data/weather_data_2016-01-07
# C:/Users/DELL/Downloads/ai_proj/training_data/training_data/weather_data/weather_data_2016-01-08
# C:/Users/DELL/Downloads/ai_proj/training_data/training_data/weather_data/weather_data_2016-01-09
# C:/Users/DELL/Downloads/ai_proj/training_data/training_data/weather_data/weather_data_2016-01-10
# C:/Users/DELL/Downloads/ai_proj/training_data/training_data/weather_data/weather_data_2016-01-11
# C:/Users/DELL/Downloads/ai_proj/training_data/training_data/weather_data/weather_data_2016-01-12
# C:/Users/DELL/Downloads/ai_proj/training_data/training_data/weather_data/weather_data_2016-01-13
# C:/Users/DELL/Downloads/ai_proj/training_data/training_data/weather_data/weather_data_2016-01-14
# C:/Users/DELL/Downloads/ai_proj/training_data/training_data/weather_data/weather_data_2016-01-15
# C:/Users/DELL/Downloads/ai_proj/training_data/training_data/weather_data/weather_data_2016-01-16
# C:/Users/DELL/Downloads/ai_proj/training_data/training_data/weather_data/weather_data_2016-01-17
# C:/Users/DELL/Downloads/ai_proj/training_data/training_data/weather_data/weather_data_2016-01-18
# C:/Users/DELL/Downloads/ai_proj/training_data/training_data/weather_data/weather_data_2016-01-19
# C:/Users/DELL/Downloads/ai_proj/training_data/training_data/weather_data/weather_data_2016-01-20
# C:/Users/DELL/Downloads/ai_proj/training_data/training_data/weather_data/weather_data_2016-01-21
#                    Time  Weather  Temprature  PM2.5
# 0   2016-01-21 07:06:27        4         1.0     49
# 1   2016-01-21 07:16:44        4         1.0     49
# 2   2016-01-21 07:32:28        4         1.0     49
# 3   2016-01-21 07:51:38        4         1.0     50
# 4   2016-01-21 08:12:29        4         1.0     50
# 5   2016-01-21 08:58:10        4         1.0     49
# 6   2016-01-21 09:22:50        4         1.0     49
# 7   2016-01-21 09:47:31        4         1.0     49
# 8   2016-01-21 19:04:38        4         1.0     44
# 9   2016-01-21 19:26:20        4         1.0     44
# 10  2016-01-21 19:36:07        4         2.0     44
# 11  2016-01-21 19:45:50        4         1.0     48
# 12  2016-01-21 19:50:38        4         1.0     48
# 13  2016-01-21 20:01:12        4         1.0     48
# 14  2016-01-21 20:10:39        4         1.0     48
# 15  2016-01-21 20:16:09        4         1.0     48
# 16  2016-01-21 20:25:50        2         1.0     48
# 17  2016-01-21 20:35:57        2         1.0     48
# 18  2016-01-21 20:45:47        2         1.0     53
# 19  2016-01-21 20:56:19        2         1.0     53
# 20  2016-01-21 21:05:35        2         1.0     53
# 21  2016-01-21 21:11:22        2         1.0     53
# 22  2016-01-21 21:21:04        2         1.0     53
# 23  2016-01-21 21:31:11        2         1.0     53
# 24  2016-01-21 21:40:58        2         1.0     53
# 25  2016-01-21 21:51:01        2         1.0     53
# 26  2016-01-21 22:01:02        2         1.0     53
# 27  2016-01-21 22:10:53        2         1.0     53
# 28  2016-01-21 22:20:37        2         1.0     53
# 29  2016-01-21 22:26:34        2         1.0     53
# 30  2016-01-21 22:35:24        2         1.0     58
# 31  2016-01-21 22:40:44        2         1.0     58
# 32  2016-01-21 22:45:45        2         1.0     58
# 33  2016-01-21 22:50:34        2         1.0     58
# 34  2016-01-21 22:55:43        2         1.0     58
# 35  2016-01-21 23:01:03        2         1.0     58
# 36  2016-01-21 23:05:50        2         1.0     58
# 37  2016-01-21 23:11:17        2         1.0     58
# 38  2016-01-21 23:15:41        2         1.0     58
# 39  2016-01-21 23:20:52        2         1.0     58
# 40  2016-01-21 23:25:27        2         1.0     58
# 41  2016-01-21 23:30:23        2         1.0     58
# 42  2016-01-21 23:35:24        2         1.0     58
# 43  2016-01-21 23:40:46        2         1.0     59
# 44  2016-01-21 23:45:44        2         1.0     59
# 45  2016-01-21 23:50:31        2         1.0     59
# 46  2016-01-21 23:55:26        2         1.0     59

# %%
file_loc = "C:/Users/DELL/Downloads/ai_proj/training_data/training_data/poi_data/poi_data"
size = len(file_loc)
#deets = pd.DataFrame(columns=["region_hash","poi_class"])


detss = pd.read_csv(file_loc, header=None)
# names=["region_hash","poi_class"])
detss=detss[0].str.split('\t',expand=True)
print(detss)
# Out:
#                                  0          1         2          3    \
# 0   74c1c25f4b283fa74a5514307b0d0278  1#11:2241  1#10:249    24:1245
# 1   08f5b445ec6b29deba62e6fd8b0325a6   20#7:249   20#5:83    2#7:166
# 2   4b7f6f4e2bf237b6cc58f57142bea5c0   4#16:249    24:913     25:332
# 3   a814069db8d32f0fa6e188f41059c6e1   1#11:498    24:332     25:581
# 4   8316146a6f78cc6d9f113f0390859417   20#7:581   20#5:83   20#4:415
# ..                               ...        ...       ...        ...
# 60  d4ec2125aff74eded207d2d915ef682f  4#16:1577  1#10:332    24:3486
# 61  82cc4851f9e4faa4e54309f8bb73fd7c   4#16:498  1#10:830    24:6308
# 62  fff4e8465d1e12621bc361276b6217cf  20#7:1494  20#5:249  20#4:1660
# 63  b05379ac3f9b7d99370d443cfd5dcc28   4#16:166  1#10:332    24:1411
# 64  fc34648599753c9e74ab238e9a4a07ad   4#16:498  1#10:166     24:996
#
#          4          5           6           7          8         9    ...  \
# 0    25:3652   20:33449     22:2324      23:913    4:13031     8:166  ...
# 1   20#2:747   20#1:996  16#12:1245  16#10:2158  16#11:415  20#8:249  ...
# 2    20:4316     22:415      4:2158      5#4:83    5#3:166   5#1:332  ...
# 3    20:5810    22:2407      4:1494        8:83    5#1:581   8#2:996  ...
# 4   20#2:166   20#1:664   16#12:332   16#10:747  16#11:498  20#8:913  ...
# ..       ...        ...         ...         ...        ...       ...  ...
# 60  25:15272  20:197125     22:1162    23:13612    4:44903    8:3818  ...
# 61   25:4897   20:56440     22:2739     23:4980    4:22576     8:996  ...
# 62   8#4:747  20#1:1494   16#12:332   16#10:581  20#8:3818   23#3:83  ...
# 63   25:1826   20:37433     22:2324     23:2241     4:9628    5#4:83  ...
# 64   25:1411   20:32951     22:1079      23:747     4:7636     8:332  ...
#
#           142      143       144        145       146      147        148  \
# 0        None     None      None       None      None     None       None
# 1        None     None      None       None      None     None       None
# 2        None     None      None       None      None     None       None
# 3        None     None      None       None      None     None       None
# 4        None     None      None       None      None     None       None
# ..        ...      ...       ...        ...       ...      ...        ...
# 60    2#8:249  2#4:581  2#5:2988  2#6:12699  2#7:2656  2#1:581  2#2:21746
# 61  2#2:16434  2#3:664      None       None      None     None       None
# 62       None     None      None       None      None     None       None
# 63       None     None      None       None      None     None       None
# 64       None     None      None       None      None     None       None
#
#          149      150      151
# 0       None     None     None
# 1       None     None     None
# 2       None     None     None
# 3       None     None     None
# 4       None     None     None
# ..       ...      ...      ...
# 60  2#3:1577  21#1:83  13#2:83
# 61      None     None     None
# 62      None     None     None
# 63      None     None     None
# 64      None     None     None
#
# [65 rows x 152 columns]

# %%
print(detss[0])
# Out:
# 0     74c1c25f4b283fa74a5514307b0d0278
# 1     08f5b445ec6b29deba62e6fd8b0325a6
# 2     4b7f6f4e2bf237b6cc58f57142bea5c0
# 3     a814069db8d32f0fa6e188f41059c6e1
# 4     8316146a6f78cc6d9f113f0390859417
#                     ...
# 60    d4ec2125aff74eded207d2d915ef682f
# 61    82cc4851f9e4faa4e54309f8bb73fd7c
# 62    fff4e8465d1e12621bc361276b6217cf
# 63    b05379ac3f9b7d99370d443cfd5dcc28
# 64    fc34648599753c9e74ab238e9a4a07ad
# Name: 0, Length: 65, dtype: object

# %%
import datetime
#iss main now we can go through file 
start_time= datetime.datetime( 2023, 4,19,0, 0, 0)
end_time=datetime.datetime(2023,4,20, 0, 0,0)

# Create a list to hold the time slots
time_slots=[]

# Loop through 10 minute intervals
while start_time<end_time:
    time_slots.append(start_time.strftime("%H:%M:%S"))
    start_time+=datetime.timedelta(minutes=10)

# # Print the time slots
tempp= 0
for slot in time_slots:
    print(slot)
    print(tempp+1)
    tempp=tempp+1
# Out:
# 00:00:00
# 1
# 00:10:00
# 2
# 00:20:00
# 3
# 00:30:00
# 4
# 00:40:00
# 5
# 00:50:00
# 6
# 01:00:00
# 7
# 01:10:00
# 8
# 01:20:00
# 9
# 01:30:00
# 10
# 01:40:00
# 11
# 01:50:00
# 12
# 02:00:00
# 13
# 02:10:00
# 14
# 02:20:00
# 15
# 02:30:00
# 16
# 02:40:00
# 17
# 02:50:00
# 18
# 03:00:00
# 19
# 03:10:00
# 20
# 03:20:00
# 21
# 03:30:00
# 22
# 03:40:00
# 23
# 03:50:00
# 24
# 04:00:00
# 25
# 04:10:00
# 26
# 04:20:00
# 27
# 04:30:00
# 28
# 04:40:00
# 29
# 04:50:00
# 30
# 05:00:00
# 31
# 05:10:00
# 32
# 05:20:00
# 33
# 05:30:00
# 34
# 05:40:00
# 35
# 05:50:00
# 36
# 06:00:00
# 37
# 06:10:00
# 38
# 06:20:00
# 39
# 06:30:00
# 40
# 06:40:00
# 41
# 06:50:00
# 42
# 07:00:00
# 43
# 07:10:00
# 44
# 07:20:00
# 45
# 07:30:00
# 46
# 07:40:00
# 47
# 07:50:00
# 48
# 08:00:00
# 49
# 08:10:00
# 50
# 08:20:00
# 51
# 08:30:00
# 52
# 08:40:00
# 53
# 08:50:00
# 54
# 09:00:00
# 55
# 09:10:00
# 56
# 09:20:00
# 57
# 09:30:00
# 58
# 09:40:00
# 59
# 09:50:00
# 60
# 10:00:00
# 61
# 10:10:00
# 62
# 10:20:00
# 63
# 10:30:00
# 64
# 10:40:00
# 65
# 10:50:00
# 66
# 11:00:00
# 67
# 11:10:00
# 68
# 11:20:00
# 69
# 11:30:00
# 70
# 11:40:00
# 71
# 11:50:00
# 72
# 12:00:00
# 73
# 12:10:00
# 74
# 12:20:00
# 75
# 12:30:00
# 76
# 12:40:00
# 77
# 12:50:00
# 78
# 13:00:00
# 79
# 13:10:00
# 80
# 13:20:00
# 81
# 13:30:00
# 82
# 13:40:00
# 83
# 13:50:00
# 84
# 14:00:00
# 85
# 14:10:00
# 86
# 14:20:00
# 87
# 14:30:00
# 88
# 14:40:00
# 89
# 14:50:00
# 90
# 15:00:00
# 91
# 15:10:00
# 92
# 15:20:00
# 93
# 15:30:00
# 94
# 15:40:00
# 95
# 15:50:00
# 96
# 16:00:00
# 97
# 16:10:00
# 98
# 16:20:00
# 99
# 16:30:00
# 100
# 16:40:00
# 101
# 16:50:00
# 102
# 17:00:00
# 103
# 17:10:00
# 104
# 17:20:00
# 105
# 17:30:00
# 106
# 17:40:00
# 107
# 17:50:00
# 108
# 18:00:00
# 109
# 18:10:00
# 110
# 18:20:00
# 111
# 18:30:00
# 112
# 18:40:00
# 113
# 18:50:00
# 114
# 19:00:00
# 115
# 19:10:00
# 116
# 19:20:00
# 117
# 19:30:00
# 118
# 19:40:00
# 119
# 19:50:00
# 120
# 20:00:00
# 121
# 20:10:00
# 122
# 20:20:00
# 123
# 20:30:00
# 124
# 20:40:00
# 125
# 20:50:00
# 126
# 21:00:00
# 127
# 21:10:00
# 128
# 21:20:00
# 129
# 21:30:00
# 130
# 21:40:00
# 131
# 21:50:00
# 132
# 22:00:00
# 133
# 22:10:00
# 134
# 22:20:00
# 135
# 22:30:00
# 136
# 22:40:00
# 137
# 22:50:00
# 138
# 23:00:00
# 139
# 23:10:00
# 140
# 23:20:00
# 141
# 23:30:00
# 142
# 23:40:00
# 143
# 23:50:00
# 144

# %%
#abb har uss ka ham har ek file kee nayee file banatay hain
#weather region start_Region_ka_count    uss_main_se_null_ka_count  konsa_time_slot
import time
import datetime
order_deets['Time']=pd.to_datetime(order_deets['Time'])
order_deets['slot'] = 0
order_deets['date'] = 0
for index, row in order_deets.iterrows():
    #abb humnay conditional insert karnaa hai new column
    current_time=row['Time'].time()
    current_date= row['Time'].date()
    current_date=current_date.strftime("%Y-%m-%d")
    found=False
    for the_slot  in range(0,len(time_slots) -1):       
        time_tuple1=datetime.datetime.strptime(time_slots[the_slot],'%H:%M:%S')
        time_only1=time_tuple1.time()
        time_tuple2=datetime.datetime.strptime(time_slots[the_slot+1],'%H:%M:%S')
        time_only2=time_tuple2.time()
        if( current_time.minute>=50 and current_time.hour ==23 ):
            found=True
            order_deets.at[index,'slot'] = 144
            order_deets.at[index,'date'] = current_date
        
        if(current_time >=time_only1 and current_time<time_only2):
            # idhar we will have a while loop which will go throught this
            for tempp in range ( 0 ,10):                
                if time_tuple1.minute== current_time.minute and time_tuple1.hour ==current_time.hour:

                    order_deets.at[index,'slot'] = the_slot+1
                    order_deets.at[index,'date'] = current_date
                    found=True
                time_tuple1 += datetime.timedelta(minutes=1)
        if(found):
            break
print(order_deets)
# Out:
#                                 order_id                         driver_id  \
# 0       97ebd0c6680f7c0535dbfdead6e51b4b  dd65fa250fca2833a3a8c16d2cf0457c
# 1       92c3ac9251cc9b5aab90b114a1e363be  c077e0297639edcb1df6189e8cda2c3d
# 2       abeefc3e2aec952468e2fd42a1649640  86dbc1b68de435957c61b5a523854b69
# 3       cb31d0be64cda3cc66b46617bf49a05c  4fadfa6eeaa694742de036dddf02b0c4
# 4       139d492189ae5a933122c098f63252b3                               NaN
# ...                                  ...                               ...
# 126310  e4a763627ae495a7da2651833149dbcc                               NaN
# 126311  da32fb63cdc463ccdf05dfb4350ebac5                               NaN
# 126312  af4473913946b0e4bdef6181039b1a0e                               NaN
# 126313  d3fd18f27ce5a1ccbd76fa4e8c79de17  5585e2fcb0d64d7e7d4f90d9746f7221
# 126314  e9cb13318f8cb17891517545cd54ffa8  4586734a64babae65e67df6f6b95bbba
#
#                             passenger_id                 start_region_hash  \
# 0       ed180d7daf639d936f1aeae4f7fb482f  4725c39a5e5f4c188d382da3910b3f3f
# 1       191a180f0a262aff3267775c4fac8972  82cc4851f9e4faa4e54309f8bb73fd7c
# 2       7029e813bb3de8cc73a8615e2785070c  fff4e8465d1e12621bc361276b6217cf
# 3       21dc133ac68e4c07803d1c2f48988a83  4b7f6f4e2bf237b6cc58f57142bea5c0
# 4       26963cc76da2d8450d8f23fc357db987  fc34648599753c9e74ab238e9a4a07ad
# ...                                  ...                               ...
# 126310  e1d2349b8373e76d324832aa36b5587b  c4ec24e0a58ebedaa1661e5c09e47bb5
# 126311  e1d2349b8373e76d324832aa36b5587b  c4ec24e0a58ebedaa1661e5c09e47bb5
# 126312  e1d2349b8373e76d324832aa36b5587b  c4ec24e0a58ebedaa1661e5c09e47bb5
# 126313  a660eadd111f58e9d050f1440aff80e7  3a43dcdff3c0b66b1acb1644ff055f9d
# 126314  0d2e9bdfd1f8a0b069eecbfda9b0b651  62afaf3288e236b389af9cfdc5206415
#
#                         dest_region_hash  Price                Time  slot  \
# 0       3e12208dd0be281c92a6ab57d9a6fb32   24.0 2016-01-01 13:37:23    82
# 1       b05379ac3f9b7d99370d443cfd5dcc28    2.0 2016-01-01 09:47:54    59
# 2       fff4e8465d1e12621bc361276b6217cf    9.0 2016-01-01 18:24:02   111
# 3       4b7f6f4e2bf237b6cc58f57142bea5c0   11.0 2016-01-01 22:13:27   134
# 4       87285a66236346350541b8815c5fae94    4.0 2016-01-01 17:00:06   103
# ...                                  ...    ...                 ...   ...
# 126310  c4ec24e0a58ebedaa1661e5c09e47bb5   12.0 2016-01-21 12:19:21    74
# 126311  c4ec24e0a58ebedaa1661e5c09e47bb5   12.0 2016-01-21 12:19:21    74
# 126312  c4ec24e0a58ebedaa1661e5c09e47bb5   12.0 2016-01-21 12:19:21    74
# 126313  b05379ac3f9b7d99370d443cfd5dcc28   32.0 2016-01-21 12:19:18    74
# 126314  d4ec2125aff74eded207d2d915ef682f    6.0 2016-01-21 12:00:41    73
#
#               date
# 0       2016-01-01
# 1       2016-01-01
# 2       2016-01-01
# 3       2016-01-01
# 4       2016-01-01
# ...            ...
# 126310  2016-01-21
# 126311  2016-01-21
# 126312  2016-01-21
# 126313  2016-01-21
# 126314  2016-01-21
#
# [126315 rows x 9 columns]

# %%
#abb har uss ka ham har ek file kee nayee file banatay hain
#weather region start_Region_ka_count    uss_main_se_null_ka_count  konsa_time_slot
import time
import datetime
rows=0
weather_deets['Time']=pd.to_datetime(order_deets['Time'])
weather_deets['slot'] = 0
weather_deets['date'] = 0
for index, row in weather_deets.iterrows():
    rows=rows+1
    #abb humnay conditional insert karnaa hai new column
    current_time = row['Time'].time()
    current_date = row['Time'].date()
    current_date=current_date.strftime("%Y-%m-%d")
    found=False
    for the_slot in range(0, len(time_slots)-1):
        time_tuple1=datetime.datetime.strptime(time_slots[the_slot],'%H:%M:%S')
        time_only1=time_tuple1.time()
        time_tuple2=datetime.datetime.strptime(time_slots[the_slot+1],'%H:%M:%S')
        time_only2=time_tuple2.time()
        varTs= 1
        vart0 = 0
        if ( current_time.minute>= 50 and current_time.hour==23):
            found=True
            weather_deets.at[index, 'slot'] = 144
            weather_deets.at[index, 'date'] = current_date
        elif(current_time>=time_only1 and current_time<time_only2):
            for i in range (vart0,10 ):
                if  time_tuple1.minute==current_time.minute and time_tuple1.hour== current_time.hour :
                   # print("slot found")
                    weather_deets.at[index,'slot'] = the_slot+1
                    weather_deets.at[index, 'date'] = current_date
                    #print(time_slots[i])
                    found=True
                time_tuple1 += datetime.timedelta(minutes=1)
        if(found):
            break
print("the rows are")
print(rows)
print(weather_deets)
weather_deets.to_csv('all_weather_with_date8.csv', index=False)
# Out:
# the rows are
# 4811
#                     Time Weather  Temprature PM2.5  slot        date
# 0    2016-01-01 13:37:23       1         4.0   177    82  2016-01-01
# 1    2016-01-01 09:47:54       1         3.0   177    59  2016-01-01
# 2    2016-01-01 18:24:02       1         3.0   177   111  2016-01-01
# 3    2016-01-01 22:13:27       1         3.0   177   134  2016-01-01
# 4    2016-01-01 17:00:06       1         3.0   177   103  2016-01-01
# ...                  ...     ...         ...   ...   ...         ...
# 4806 2016-01-03 22:06:04       2         1.0    58   133  2016-01-03
# 4807 2016-01-03 01:35:46       2         1.0    59    10  2016-01-03
# 4808 2016-01-03 17:37:46       2         1.0    59   106  2016-01-03
# 4809 2016-01-03 22:29:52       2         1.0    59   135  2016-01-03
# 4810 2016-01-03 18:28:01       2         1.0    59   111  2016-01-03
#
# [4811 rows x 6 columns]

# %%
#weather_and_order=pd.merge(weather_dets,order_dets )
# print(order_dets)
# weather_and_order=weather_dets.merge(order_dets)
# weather_and_order.to_csv('data6.csv', index=False)
#weather_dets.to_csv('data7.csv', index=False)
#order_dets.to_csv('data8.csv', index=False)

# %%
len(detss[65])
print(detss[0])
#POI_dataframe.to_csv("POI_dataframe1.csv")
# Out:
# 0     74c1c25f4b283fa74a5514307b0d0278
# 1     08f5b445ec6b29deba62e6fd8b0325a6
# 2     4b7f6f4e2bf237b6cc58f57142bea5c0
# 3     a814069db8d32f0fa6e188f41059c6e1
# 4     8316146a6f78cc6d9f113f0390859417
#                     ...
# 60    d4ec2125aff74eded207d2d915ef682f
# 61    82cc4851f9e4faa4e54309f8bb73fd7c
# 62    fff4e8465d1e12621bc361276b6217cf
# 63    b05379ac3f9b7d99370d443cfd5dcc28
# 64    fc34648599753c9e74ab238e9a4a07ad
# Name: 0, Length: 65, dtype: object

# %%
order_count = order_deets.groupby(["slot", "start_region_hash","date"])["order_id","driver_id"].count().reset_index()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12336\3224662826.py:3: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   order_count = order_deets.groupby(["slot", "start_region_hash","date"])["order_id","driver_id"].count().reset_index()

# %%
order_weather = pd.merge(order_count, weather_deets,on=['slot','date'], how='left')

# %%
#now finding total facilities in that sector
order_weather['total_facilities_in_area']=0
for index, row in order_weather.iterrows():
    start_region_hash_value = row['start_region_hash']
    total=0
    for loc in range (0, len(detss[0])):
           if start_region_hash_value.strip()== detss[0][loc].strip():
                  j=loc
                  for i in range(1,152):
                            if(detss[i][j]!=None):
                                feature_and_value=detss[i][j]
                                if feature_and_value != None:
                                    feat,value=feature_and_value.split(':')
                                    total=total+int(value)
                                    order_weather.at[index, 'total_facilities_in_area'] = total

# %%
order_weather['gap']=order_weather['order_id']-order_weather[ 'driver_id']

# %%
order_weather=order_weather.rename(columns ={'order_id': 'number_of_orders','driver_id':'requests_entertained'})

# %%
order_weather=pd.merge(order_weather,cluster_map, left_on='start_region_hash',right_on='region_hash',how='left')

# %%
order_weather.to_csv("wonderland12.csv")

# %%
##################LINEAR REGRESSION#########################
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.model_selection import learning_curve
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.linear_model import LinearRegression


data_f=pd.read_csv('wonderland12.csv')
X_trainn,X_test,y_trainn,y_test=train_test_split(data_f[['id_region', 'slot']], data_f['gap'],test_size=0.2,random_state=42)

encoder = OneHotEncoder(sparse=False)
X_train_encoded = encoder.fit_transform(X_trainn[['id_region']])
X_test_encoded = encoder.transform(X_test[['id_region']])

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_trainn[['slot']])
X_test_scaled = scaler.transform(X_test[['slot']])
trainXfin = np.concatenate([X_train_encoded, X_train_scaled], axis=1)
testXFin = np.concatenate([X_test_encoded, X_test_scaled], axis=1)

TemModell = LinearRegression()
DataSize_Trainingg, satascores_Training, scores_testin = learning_curve(TemModell, X_trainn, y_trainn, cv=5)
mean_of_trainingg = np.mean(satascores_Training, axis=1)
standard_dev_trainn = np.std(satascores_Training, axis=1)
mean_of_testt = np.mean(scores_testin, axis=1)
standard_deviate_test = np.std(scores_testin, axis=1)

plt.plot(DataSize_Trainingg, mean_of_trainingg)
plt.plot(DataSize_Trainingg, mean_of_testt)
plt.xlabel('Training Set number of samples')
plt.ylabel('scores_train and scores_test')
plt.show()

TemModell.fit(trainXfin, y_trainn)



# Predict on the test data
pred_yi = TemModell.predict(testXFin)
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y_test, pred_yi)
print('mae:',mae)
# Out:
# c:\Users\DELL\anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:828: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# mae: 0.4660162940791283

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np

data_f = pd.read_csv('wonderland12.csv')


X_trainn,X_test,y_trainn, y_test = train_test_split(data_f[['id_region', 'slot']], data_f['gap'],test_size=0.2,random_state=42)


encoder = OneHotEncoder(sparse=False)
X_train_encoded = encoder.fit_transform(X_trainn[['id_region']])
X_test_encoded = encoder.transform(X_test[['id_region']])


scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_trainn[['slot']])
X_test_scaled = scaler.transform(X_test[['slot']])
var = 1

trainXfin = np.concatenate([X_train_encoded, X_train_scaled], axis=var)
print("")
testXFin = np.concatenate([X_test_encoded, X_test_scaled], axis=1)

alpha = 1  
TemModell = Ridge(alpha=alpha)
DataSize_Trainingg, satascores_Training, scores_testin = learning_curve(TemModell, X_trainn, y_trainn, cv=5)
mean_of_trainingg = np.mean(satascores_Training, axis=1)
standard_dev_trainn = np.std(satascores_Training, axis=1)
mean_of_testt = np.mean(scores_testin, axis=1)
standard_deviate_test = np.std(scores_testin, axis=1)

plt.plot(DataSize_Trainingg, mean_of_trainingg)
plt.plot(DataSize_Trainingg, mean_of_testt)
plt.xlabel('Training Set number of samples')
plt.ylabel('scores_train and scores_test')
plt.show()
TemModell.fit(trainXfin, y_trainn)
pred_yi = TemModell.predict(testXFin)
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y_test, pred_yi)
print('mae:',mae)
# Out:
# c:\Users\DELL\anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:828: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# mae: 0.466025029600761

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder

checkDf = pd.read_csv('wonderland12.csv')
TempLabEnc = LabelEncoder()
data_f['id_region'] = TempLabEnc.fit_transform(data_f['id_region'])
X_trainn,X_test,y_trainn,y_test=train_test_split(data_f[['id_region', 'slot']],data_f['gap'],test_size=0.3,random_state=42)
ModClasf = DecisionTreeClassifier()

###
DataSize_Trainingg, satascores_Training, scores_testin = learning_curve(TemModell, X_trainn, y_trainn, cv=5)
mean_of_trainingg = np.mean(satascores_Training, axis=1)
standard_dev_trainn = np.std(satascores_Training, axis=1)
mean_of_testt = np.mean(scores_testin, axis=1)
standard_deviate_test = np.std(scores_testin, axis=1)

plt.plot(DataSize_Trainingg, mean_of_trainingg)
plt.plot(DataSize_Trainingg, mean_of_testt)
plt.xlabel('Training Set number of samples')
plt.ylabel('scores_train and scores_test')
plt.show()


###
ModClasf.fit(X_trainn, y_trainn)
pred_yi = ModClasf.predict(X_test)
out_accuracy = accuracy_score(y_test, pred_yi)
print("accuracy is: ",out_accuracy)
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y_test, pred_yi)
print('mae:',mae)
# Out:
# accuracy is:  0.897551477648565
# mae: 0.20367011629147552

# %%
print(detss[1])
# Out:
# 0     1#11:2241
# 1      20#7:249
# 2      4#16:249
# 3      1#11:498
# 4      20#7:581
#         ...
# 60    4#16:1577
# 61     4#16:498
# 62    20#7:1494
# 63     4#16:166
# 64     4#16:498
# Name: 1, Length: 65, dtype: object

# %%
print(detss)
# Out:
#                                  0          1         2          3    \
# 0   74c1c25f4b283fa74a5514307b0d0278  1#11:2241  1#10:249    24:1245
# 1   08f5b445ec6b29deba62e6fd8b0325a6   20#7:249   20#5:83    2#7:166
# 2   4b7f6f4e2bf237b6cc58f57142bea5c0   4#16:249    24:913     25:332
# 3   a814069db8d32f0fa6e188f41059c6e1   1#11:498    24:332     25:581
# 4   8316146a6f78cc6d9f113f0390859417   20#7:581   20#5:83   20#4:415
# ..                               ...        ...       ...        ...
# 60  d4ec2125aff74eded207d2d915ef682f  4#16:1577  1#10:332    24:3486
# 61  82cc4851f9e4faa4e54309f8bb73fd7c   4#16:498  1#10:830    24:6308
# 62  fff4e8465d1e12621bc361276b6217cf  20#7:1494  20#5:249  20#4:1660
# 63  b05379ac3f9b7d99370d443cfd5dcc28   4#16:166  1#10:332    24:1411
# 64  fc34648599753c9e74ab238e9a4a07ad   4#16:498  1#10:166     24:996
#
#          4          5           6           7          8         9    ...  \
# 0    25:3652   20:33449     22:2324      23:913    4:13031     8:166  ...
# 1   20#2:747   20#1:996  16#12:1245  16#10:2158  16#11:415  20#8:249  ...
# 2    20:4316     22:415      4:2158      5#4:83    5#3:166   5#1:332  ...
# 3    20:5810    22:2407      4:1494        8:83    5#1:581   8#2:996  ...
# 4   20#2:166   20#1:664   16#12:332   16#10:747  16#11:498  20#8:913  ...
# ..       ...        ...         ...         ...        ...       ...  ...
# 60  25:15272  20:197125     22:1162    23:13612    4:44903    8:3818  ...
# 61   25:4897   20:56440     22:2739     23:4980    4:22576     8:996  ...
# 62   8#4:747  20#1:1494   16#12:332   16#10:581  20#8:3818   23#3:83  ...
# 63   25:1826   20:37433     22:2324     23:2241     4:9628    5#4:83  ...
# 64   25:1411   20:32951     22:1079      23:747     4:7636     8:332  ...
#
#           142      143       144        145       146      147        148  \
# 0        None     None      None       None      None     None       None
# 1        None     None      None       None      None     None       None
# 2        None     None      None       None      None     None       None
# 3        None     None      None       None      None     None       None
# 4        None     None      None       None      None     None       None
# ..        ...      ...       ...        ...       ...      ...        ...
# 60    2#8:249  2#4:581  2#5:2988  2#6:12699  2#7:2656  2#1:581  2#2:21746
# 61  2#2:16434  2#3:664      None       None      None     None       None
# 62       None     None      None       None      None     None       None
# 63       None     None      None       None      None     None       None
# 64       None     None      None       None      None     None       None
#
#          149      150      151
# 0       None     None     None
# 1       None     None     None
# 2       None     None     None
# 3       None     None     None
# 4       None     None     None
# ..       ...      ...      ...
# 60  2#3:1577  21#1:83  13#2:83
# 61      None     None     None
# 62      None     None     None
# 63      None     None     None
# 64      None     None     None
#
# [65 rows x 152 columns]
